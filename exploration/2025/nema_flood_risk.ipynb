# %% [markdown]
# # NEMA flood risk
# <!-- markdownlint-disable MD013 -->

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
from src.datasources import codab
from src.utils import blob
from src.constants import *

# %%
adm2 = codab.load_codab_from_blob(aoi_only=True, admin_level=2)

# %%
adm2
# Out:
#         ADM2_EN ADM2_PCODE  ADM1_EN ADM1_PCODE  ADM0_EN ADM0_PCODE  \
# 2        Abadam   NG008001    Borno      NG008  Nigeria         NG
# 68   Askira/Uba   NG008002    Borno      NG008  Nigeria         NG
# 82         Bade   NG036001     Yobe      NG036  Nigeria         NG
# 90         Bama   NG008003    Borno      NG008  Nigeria         NG
# 99         Bayo   NG008004    Borno      NG008  Nigeria         NG
# ..          ...        ...      ...        ...      ...        ...
# 709      Toungo   NG002019  Adamawa      NG002  Nigeria         NG
# 762  Yola North   NG002020  Adamawa      NG002  Nigeria         NG
# 763  Yola South   NG002021  Adamawa      NG002  Nigeria         NG
# 765    Yunusari   NG036016     Yobe      NG036  Nigeria         NG
# 766    Yusufari   NG036017     Yobe      NG036  Nigeria         NG
#
#            DATE     VALIDON VALIDTO  \
# 2    2017-03-31  2019-04-17    None
# 68   2017-03-31  2019-04-17    None
# 82   2017-03-31  2019-04-17    None
# 90   2017-03-31  2019-04-17    None
# 99   2017-03-31  2019-04-17    None
# ..          ...         ...     ...
# 709  2017-03-31  2019-04-17    None
# 762  2017-03-31  2019-04-17    None
# 763  2017-03-31  2019-04-17    None
# 765  2017-03-31  2019-04-17    None
# 766  2017-03-31  2019-04-17    None
#
#                                               geometry
# 2    POLYGON ((13.11029 13.10963, 13.10815 13.11404...
# 68   POLYGON ((13.09852 10.44508, 13.09352 10.44667...
# 82   MULTIPOLYGON (((11.18769 12.50815, 11.18360 12...
# 90   POLYGON ((13.99056 11.31251, 13.97581 11.30513...
# 99   POLYGON ((11.65688 10.19681, 11.60128 10.20806...
# ..                                                 ...
# 709  POLYGON ((12.21046 7.97042, 12.20300 7.96432, ...
# 762  POLYGON ((12.40447 9.25767, 12.40226 9.26307, ...
# 763  POLYGON ((12.43708 9.21300, 12.43732 9.21285, ...
# 765  POLYGON ((12.13949 13.09935, 12.14254 13.09896...
# 766  POLYGON ((11.32417 13.15145, 11.32829 13.14117...
#
# [65 rows x 10 columns]

# %%
blob_name = f"{blob.PROJECT_PREFIX}/raw/AA-nigeria_data/NEMA/Flood Risk Excel Data 2.xlsx"

# %%
df = blob.load_excel_from_blob(blob_name)

# %%
df = df[df["ADM1_PCODE"].isin(AOI_ADM1_PCODES)]

# %%
df["Riverine Flood Risk"].value_counts()
# Out:
# Riverine Flood Risk
# High      19
# Medium    14
# Low        6
# Name: count, dtype: int64

# %%
df["Flash Flood Risk"].value_counts()
# Out:
# Flash Flood Risk
# High      29
# Medium    17
# Low       14
# Name: count, dtype: int64

# %%
df["Coastal Flood Risk"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.merge(adm2)
# Out:
#        ADM2_EN ADM2_PCODE  ADM1_EN ADM1_PCODE    STATE ADM2_PCODE2  \
# 0       Abadam   NG008001    Borno      NG008    Borno    NG008001
# 1   Askira/Uba   NG008002    Borno      NG008    Borno    NG008002
# 2         Bade   NG036001     Yobe      NG036     Yobe    NG036001
# 3         Bama   NG008003    Borno      NG008    Borno    NG008003
# 4         Bayo   NG008004    Borno      NG008    Borno    NG008004
# ..         ...        ...      ...        ...      ...         ...
# 60      Toungo   NG002019  Adamawa      NG002  Adamawa    NG002019
# 61  Yola North   NG002020  Adamawa      NG002  Adamawa    NG002020
# 62  Yola South   NG002021  Adamawa      NG002  Adamawa    NG002021
# 63    Yunusari   NG036016     Yobe      NG036     Yobe    NG036016
# 64    Yusufari   NG036017     Yobe      NG036     Yobe    NG036017
#
#    Riverine Flood Risk Flash Flood Risk Coastal Flood Risk  \
# 0                  Low              Low                NaN
# 1               Medium              Low                NaN
# 2                 High             High                NaN
# 3               Medium           Medium                NaN
# 4                  NaN             High                NaN
# ..                 ...              ...                ...
# 60                 NaN              NaN                NaN
# 61                High             High                NaN
# 62                High             High                NaN
# 63                 NaN           Medium                NaN
# 64                 NaN              Low                NaN
#
#                                 Comments  Column3  ADM0_EN ADM0_PCODE  \
# 0                                 <Null>      NaN  Nigeria         NG
# 1                                 <Null>      NaN  Nigeria         NG
# 2   PREVALENCE OF RIVERINE FLOOD IS MORE      NaN  Nigeria         NG
# 3                                 <Null>      NaN  Nigeria         NG
# 4                                 <Null>      NaN  Nigeria         NG
# ..                                   ...      ...      ...        ...
# 60                                <Null>      NaN  Nigeria         NG
# 61                                <Null>      NaN  Nigeria         NG
# 62                                <Null>      NaN  Nigeria         NG
# 63                                <Null>      NaN  Nigeria         NG
# 64                                <Null>      NaN  Nigeria         NG
#
#           DATE     VALIDON VALIDTO  \
# 0   2017-03-31  2019-04-17    None
# 1   2017-03-31  2019-04-17    None
# 2   2017-03-31  2019-04-17    None
# 3   2017-03-31  2019-04-17    None
# 4   2017-03-31  2019-04-17    None
# ..         ...         ...     ...
# 60  2017-03-31  2019-04-17    None
# 61  2017-03-31  2019-04-17    None
# 62  2017-03-31  2019-04-17    None
# 63  2017-03-31  2019-04-17    None
# 64  2017-03-31  2019-04-17    None
#
#                                              geometry
# 0   POLYGON ((13.11029 13.10963, 13.10815 13.11404...
# 1   POLYGON ((13.09852 10.44508, 13.09352 10.44667...
# 2   MULTIPOLYGON (((11.18769 12.50815, 11.18360 12...
# 3   POLYGON ((13.99056 11.31251, 13.97581 11.30513...
# 4   POLYGON ((11.65688 10.19681, 11.60128 10.20806...
# ..                                                ...
# 60  POLYGON ((12.21046 7.97042, 12.20300 7.96432, ...
# 61  POLYGON ((12.40447 9.25767, 12.40226 9.26307, ...
# 62  POLYGON ((12.43708 9.21300, 12.43732 9.21285, ...
# 63  POLYGON ((12.13949 13.09935, 12.14254 13.09896...
# 64  POLYGON ((11.32417 13.15145, 11.32829 13.14117...
#
# [65 rows x 17 columns]
