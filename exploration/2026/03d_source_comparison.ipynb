# %%
import ocha_stratus as stratus
import matplotlib.pyplot as plt
import pandas as pd
from dotenv import load_dotenv  

load_dotenv()
# Out:
# True

# %%
gdf_gs = stratus.load_geoparquet_from_blob("ds-aa-nga-flooding/processed/groundsource_flood_sel.parquet")
df_nihsa = stratus.load_parquet_from_blob(
    "ds-aa-nga-flooding/processed/nihsa/floodhistory_2013_2023_sel_lgas.parquet"
)
df_fs =
