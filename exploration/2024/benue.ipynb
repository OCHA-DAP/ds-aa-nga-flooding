# %% [markdown]
# # Benue

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import geopandas as gpd

from src.datasources import hydrosheds, codab
from src.constants import *

# %%
adm2 = codab.load_codab(admin_level=2)
adm2_a = adm2[adm2["ADM1_PCODE"] == ADAMAWA]

# %%
hydrosheds.process_benue_aoi()
# Out:
# /Users/tdowning/OCHA/repos/ds-aa-nga-flooding/src/datasources/hydrosheds.py:43: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   benue_aoi.to_file(
# WARNING:fiona._env:Normalized/laundered field name: 'index_right' to 'index_righ'

# %%
benue = hydrosheds.load_benue_aoi()

# %%
ax = adm2_a.plot(alpha=0.2)
benue.plot(ax=ax)
# Out:
# <Axes: >
